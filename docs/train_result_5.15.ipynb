# %%
# Change directory to VSCode workspace root so that relative path loads work correctly. Turn this addition off with the DataScience.changeDirOnImportExport setting
import os
try:
	os.chdir(os.path.join(os.getcwd(), '..'))
	print(os.getcwd())
except:
	pass

# %%
import sys
import os
sys.path.append('.')
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %%
from research.detection.kernel import Kernel  # noqa: E402
# Out:
# Using TensorFlow backend.

# %%
# 训练模型
# all/heads：训练整个网络/网络尾部 详见declaration
# epoch：目标迭代轮数，注意不是训练多少轮

# k = Kernel()
# k.build('training')
# # k.load_weights(special='coco')
# k.load_weights('data/__cache__/detection/__logs__/' +
#                'detection20190509T1729/mask_rcnn_detection_3000.h5')
# k.train(epoch=4500, layers='all')
# # k.train(epoch=3000, learning_rate_coefficient=1, layers='heads')

# %%
# 读取训练模型并评估

import matplotlib.pyplot as plt  # noqa： E402
import numpy as np  # noqa： E402

k = Kernel()
k.build('inference')
prefix = 'data/__cache__/detection/__logs__/detection20190509T1729'

x = np.arange(3000, 4500)
x = [x_i for x_i in x if x_i % 10 == 0]

y = []
for i in x:
    mid = str(i).zfill(4)
    k.load_weights(path=f'{prefix}/mask_rcnn_detection_{mid}.h5')
    y.append(k.eval())
plt.plot(x, y)

plt.savefig("train_res_1000_4500.png")
# 下面行不写会出现 [<matplotlib.lines.Line2D at 0x111814390>] 字样
plt.show()
# Out:
# Configurations:
# BACKBONE                       resnet101
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     1
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# COMPUTE_BACKBONE_SHAPE         None
# DETECTION_MAX_INSTANCES        100
# DETECTION_MIN_CONFIDENCE       0.7
# DETECTION_NMS_THRESHOLD        0.3
# FPN_CLASSIF_FC_LAYERS_SIZE     1024
# GPU_COUNT                      1
# GRADIENT_CLIP_NORM             5.0
# IMAGES_PER_GPU                 1
# IMAGE_CHANNEL_COUNT            3
# IMAGE_MAX_DIM                  128
# IMAGE_META_SIZE                43
# IMAGE_MIN_DIM                  128
# IMAGE_MIN_SCALE                0
# IMAGE_RESIZE_MODE              square
# IMAGE_SHAPE                    [128 128   3]
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.001
# LOSS_WEIGHTS                   {'rpn_class_loss': 1.0, 'rpn_bbox_loss': 1.0, 'mrcnn_class_loss': 1.0, 'mrcnn_bbox_loss': 1.0, 'mrcnn_mask_loss': 1.0}
# MASK_POOL_SIZE                 14
# MASK_SHAPE                     [28, 28]
# MAX_GT_INSTANCES               100
# MEAN_PIXEL                     [123.7 116.8 103.9]
# MINI_MASK_SHAPE                (56, 56)
# NAME                           detection
# NUM_CLASSES                    31
# POOL_SIZE                      7
# POST_NMS_ROIS_INFERENCE        1000
# POST_NMS_ROIS_TRAINING         2000
# PRE_NMS_LIMIT                  6000
# ROI_POSITIVE_RATIO             0.33
# RPN_ANCHOR_RATIOS              [0.5, 1, 2]
# RPN_ANCHOR_SCALES              (8, 16, 32, 64, 128)
# RPN_ANCHOR_STRIDE              1
# RPN_BBOX_STD_DEV               [0.1 0.1 0.2 0.2]
# RPN_NMS_THRESHOLD              0.7
# RPN_TRAIN_ANCHORS_PER_IMAGE    256
# STEPS_PER_EPOCH                100
# TOP_DOWN_PYRAMID_SIZE          256
# TRAIN_BN                       False
# TRAIN_ROIS_PER_IMAGE           32
# USE_MINI_MASK                  True
# USE_RPN_ROIS                   True
# VALIDATION_STEPS               5
# WEIGHT_DECAY                   0.0001
#
#
# WARNING:tensorflow:From /home/sh/anaconda3/envs/dl/lib/python3.6/site-packages/tensorflow/python/ops/sparse_ops.py:1165: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# Re-starting from epoch 3000
# Re-starting from epoch 3010
# Re-starting from epoch 3020
# Re-starting from epoch 3030
# Re-starting from epoch 3040
# Re-starting from epoch 3050
# Re-starting from epoch 3060
# Re-starting from epoch 3070
# Re-starting from epoch 3080
# Re-starting from epoch 3090
# Re-starting from epoch 3100
# Re-starting from epoch 3110
# Re-starting from epoch 3120
# Re-starting from epoch 3130
# Re-starting from epoch 3140
# Re-starting from epoch 3150
# Re-starting from epoch 3160
# Re-starting from epoch 3170
# Re-starting from epoch 3180
# Re-starting from epoch 3190
# Re-starting from epoch 3200
# Re-starting from epoch 3210
# Re-starting from epoch 3220
# Re-starting from epoch 3230
# Re-starting from epoch 3240
# Re-starting from epoch 3250
# Re-starting from epoch 3260
# Re-starting from epoch 3270
# Re-starting from epoch 3280
# Re-starting from epoch 3290
# Re-starting from epoch 3300
# Re-starting from epoch 3310
# Re-starting from epoch 3320
# Re-starting from epoch 3330
# Re-starting from epoch 3340
# Re-starting from epoch 3350
# Re-starting from epoch 3360
# Re-starting from epoch 3370
# Re-starting from epoch 3380
# Re-starting from epoch 3390
# Re-starting from epoch 3400
# Re-starting from epoch 3410
# Re-starting from epoch 3420
# Re-starting from epoch 3430
# Re-starting from epoch 3440
# Re-starting from epoch 3450
# Re-starting from epoch 3460
# Re-starting from epoch 3470
# Re-starting from epoch 3480
# Re-starting from epoch 3490
# Re-starting from epoch 3500
# Re-starting from epoch 3510
# Re-starting from epoch 3520
# Re-starting from epoch 3530
# Re-starting from epoch 3540
# Re-starting from epoch 3550
# Re-starting from epoch 3560
# Re-starting from epoch 3570
# Re-starting from epoch 3580
# Re-starting from epoch 3590
# Re-starting from epoch 3600
# Re-starting from epoch 3610
# Re-starting from epoch 3620
# Re-starting from epoch 3630
# Re-starting from epoch 3640
# Re-starting from epoch 3650
# Re-starting from epoch 3660
# Re-starting from epoch 3670
# Re-starting from epoch 3680
# Re-starting from epoch 3690
# Re-starting from epoch 3700
# Re-starting from epoch 3710
# Re-starting from epoch 3720
# Re-starting from epoch 3730
# Re-starting from epoch 3740
# Re-starting from epoch 3750
# Re-starting from epoch 3760
# Re-starting from epoch 3770
# Re-starting from epoch 3780
# Re-starting from epoch 3790
# Re-starting from epoch 3800
# Re-starting from epoch 3810
# Re-starting from epoch 3820
# Re-starting from epoch 3830
# Re-starting from epoch 3840
# Re-starting from epoch 3850
# Re-starting from epoch 3860
# Re-starting from epoch 3870
# Re-starting from epoch 3880
# Re-starting from epoch 3890
# Re-starting from epoch 3900
# Re-starting from epoch 3910
# Re-starting from epoch 3920
# Re-starting from epoch 3930
# Re-starting from epoch 3940
# Re-starting from epoch 3950
# Re-starting from epoch 3960
# Re-starting from epoch 3970
# Re-starting from epoch 3980
# Re-starting from epoch 3990
# Re-starting from epoch 4000
# Re-starting from epoch 4010
# Re-starting from epoch 4020
# Re-starting from epoch 4030
# Re-starting from epoch 4040
# Re-starting from epoch 4050
# Re-starting from epoch 4060
# Re-starting from epoch 4070
# Re-starting from epoch 4080
# Re-starting from epoch 4090
# Re-starting from epoch 4100
# Re-starting from epoch 4110
# Re-starting from epoch 4120
# Re-starting from epoch 4130
# Re-starting from epoch 4140
# Re-starting from epoch 4150
# Re-starting from epoch 4160
# Re-starting from epoch 4170
# Re-starting from epoch 4180
# Re-starting from epoch 4190
# Re-starting from epoch 4200
# Re-starting from epoch 4210
# Re-starting from epoch 4220
# Re-starting from epoch 4230
# Re-starting from epoch 4240
# Re-starting from epoch 4250
# Re-starting from epoch 4260
# Re-starting from epoch 4270
# Re-starting from epoch 4280
# Re-starting from epoch 4290
# Re-starting from epoch 4300
# Re-starting from epoch 4310
# Re-starting from epoch 4320
# Re-starting from epoch 4330
# Re-starting from epoch 4340
# Re-starting from epoch 4350
# Re-starting from epoch 4360
# Re-starting from epoch 4370
# Re-starting from epoch 4380
# Re-starting from epoch 4390
# Re-starting from epoch 4400
# Re-starting from epoch 4410
# Re-starting from epoch 4420
# Re-starting from epoch 4430
# Re-starting from epoch 4440
# Re-starting from epoch 4450
# Re-starting from epoch 4460
# Re-starting from epoch 4470
# Re-starting from epoch 4480
# Re-starting from epoch 4490

# %%
curv = zip(x,y)
for x in curv:
  print(x)
# Out:
# (3000, 0.7972972972972973)
# (3010, 0.7567567567567568)
# (3020, 0.7702702702702703)
# (3030, 0.7635135135135135)
# (3040, 0.7702702702702703)
# (3050, 0.7905405405405406)
# (3060, 0.8006756756756757)
# (3070, 0.8108108108108109)
# (3080, 0.8277027027027027)
# (3090, 0.7736486486486487)
# (3100, 0.7837837837837838)
# (3110, 0.8040540540540541)
# (3120, 0.7635135135135135)
# (3130, 0.7297297297297297)
# (3140, 0.8378378378378378)
# (3150, 0.7804054054054054)
# (3160, 0.7871621621621622)
# (3170, 0.8209459459459459)
# (3180, 0.7668918918918919)
# (3190, 0.7871621621621622)
# (3200, 0.8006756756756757)
# (3210, 0.7972972972972973)
# (3220, 0.8108108108108109)
# (3230, 0.7736486486486487)
# (3240, 0.8108108108108109)
# (3250, 0.7837837837837838)
# (3260, 0.8243243243243243)
# (3270, 0.8040540540540541)
# (3280, 0.8209459459459459)
# (3290, 0.8108108108108109)
# (3300, 0.8040540540540541)
# (3310, 0.8040540540540541)
# (3320, 0.8108108108108109)
# (3330, 0.7905405405405406)
# (3340, 0.793918918918919)
# (3350, 0.7736486486486487)
# (3360, 0.831081081081081)
# (3370, 0.8108108108108109)
# (3380, 0.8141891891891891)
# (3390, 0.8344594594594594)
# (3400, 0.8040540540540541)
# (3410, 0.8243243243243243)
# (3420, 0.8344594594594594)
# (3430, 0.8277027027027027)
# (3440, 0.8141891891891891)
# (3450, 0.8378378378378378)
# (3460, 0.8108108108108109)
# (3470, 0.8175675675675675)
# (3480, 0.831081081081081)
# (3490, 0.831081081081081)
# (3500, 0.8175675675675675)
# (3510, 0.8243243243243243)
# (3520, 0.8277027027027027)
# (3530, 0.8108108108108109)
# (3540, 0.8445945945945946)
# (3550, 0.8378378378378378)
# (3560, 0.8243243243243243)
# (3570, 0.8378378378378378)
# (3580, 0.8141891891891891)
# (3590, 0.8108108108108109)
# (3600, 0.8243243243243243)
# (3610, 0.8040540540540541)
# (3620, 0.8108108108108109)
# (3630, 0.8243243243243243)
# (3640, 0.831081081081081)
# (3650, 0.8243243243243243)
# (3660, 0.831081081081081)
# (3670, 0.8074324324324325)
# (3680, 0.8141891891891891)
# (3690, 0.8277027027027027)
# (3700, 0.8513513513513513)
# (3710, 0.8445945945945946)
# (3720, 0.8378378378378378)
# (3730, 0.8513513513513513)
# (3740, 0.8209459459459459)
# (3750, 0.831081081081081)
# (3760, 0.8344594594594594)
# (3770, 0.8378378378378378)
# (3780, 0.8108108108108109)
# (3790, 0.831081081081081)
# (3800, 0.8378378378378378)
# (3810, 0.8445945945945946)
# (3820, 0.8175675675675675)
# (3830, 0.8175675675675675)
# (3840, 0.8277027027027027)
# (3850, 0.847972972972973)
# (3860, 0.847972972972973)
# (3870, 0.8513513513513513)
# (3880, 0.8513513513513513)
# (3890, 0.8581081081081081)
# (3900, 0.8581081081081081)
# (3910, 0.8581081081081081)
# (3920, 0.8513513513513513)
# (3930, 0.8412162162162162)
# (3940, 0.8277027027027027)
# (3950, 0.8277027027027027)
# (3960, 0.847972972972973)
# (3970, 0.831081081081081)
# (3980, 0.8378378378378378)
# (3990, 0.8243243243243243)
# (4000, 0.847972972972973)
# (4010, 0.8412162162162162)
# (4020, 0.8175675675675675)
# (4030, 0.8378378378378378)
# (4040, 0.8344594594594594)
# (4050, 0.8243243243243243)
# (4060, 0.8344594594594594)
# (4070, 0.8175675675675675)
# (4080, 0.831081081081081)
# (4090, 0.831081081081081)
# (4100, 0.8277027027027027)
# (4110, 0.8175675675675675)
# (4120, 0.8141891891891891)
# (4130, 0.8412162162162162)
# (4140, 0.8277027027027027)
# (4150, 0.8277027027027027)
# (4160, 0.8141891891891891)
# (4170, 0.8141891891891891)
# (4180, 0.8209459459459459)
# (4190, 0.8412162162162162)
# (4200, 0.8344594594594594)
# (4210, 0.8243243243243243)
# (4220, 0.8513513513513513)
# (4230, 0.8445945945945946)
# (4240, 0.8412162162162162)
# (4250, 0.8513513513513513)
# (4260, 0.8614864864864865)
# (4270, 0.8445945945945946)
# (4280, 0.8412162162162162)
# (4290, 0.8445945945945946)
# (4300, 0.8445945945945946)
# (4310, 0.8513513513513513)
# (4320, 0.8445945945945946)
# (4330, 0.847972972972973)
# (4340, 0.8243243243243243)
# (4350, 0.8209459459459459)
# (4360, 0.8277027027027027)
# (4370, 0.8445945945945946)
# (4380, 0.8074324324324325)
# (4390, 0.8378378378378378)
# (4400, 0.8209459459459459)
# (4410, 0.8445945945945946)
# (4420, 0.8141891891891891)
# (4430, 0.8277027027027027)
# (4440, 0.8412162162162162)
# (4450, 0.8074324324324325)
# (4460, 0.8243243243243243)
# (4470, 0.831081081081081)
# (4480, 0.8445945945945946)
# (4490, 0.8412162162162162)
