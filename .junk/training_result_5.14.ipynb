# %%
# Change directory to VSCode workspace root so that relative path loads work correctly. Turn this addition off with the DataScience.changeDirOnImportExport setting
import os
try:
	os.chdir(os.path.join(os.getcwd(), '..'))
	print(os.getcwd())
except:
	pass

# %%
import sys
import os
sys.path.append('.')
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %%
from research.detection.kernel import Kernel  # noqa: E402
# Out:
# Using TensorFlow backend.

# %%
# 训练模型
# all/heads：训练整个网络/网络尾部 详见declaration
# epoch：目标迭代轮数，注意不是训练多少轮

# k = Kernel()
# k.build('training')
# # k.load_weights(special='coco')
# k.load_weights('data/__cache__/detection/__logs__/' +
#                'detection20190509T1729/mask_rcnn_detection_1600.h5')
# # k.train(epoch=2400, layers='all')
# k.train(epoch=3000, learning_rate_coefficient=1, layers='heads')

# %%
# 读取训练模型并评估

import matplotlib.pyplot as plt  # noqa： E402
import numpy as np  # noqa： E402

k = Kernel()
k.build('inference')
prefix = 'data/__cache__/detection/__logs__/detection20190509T1729'

x = np.arange(1000, 3001)
x = [x_i for x_i in x if x_i % 10 == 0]

y = []
for i in x:
    mid = str(i).zfill(4)
    k.load_weights(path=f'{prefix}/mask_rcnn_detection_{mid}.h5')
    y.append(k.eval())
plt.plot(x, y)

plt.savefig("train_res_1000_3000.png")
# 下面行不写会出现 [<matplotlib.lines.Line2D at 0x111814390>] 字样
plt.show()
# Out:
# Configurations:
# BACKBONE                       resnet101
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     1
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# COMPUTE_BACKBONE_SHAPE         None
# DETECTION_MAX_INSTANCES        100
# DETECTION_MIN_CONFIDENCE       0.7
# DETECTION_NMS_THRESHOLD        0.3
# FPN_CLASSIF_FC_LAYERS_SIZE     1024
# GPU_COUNT                      1
# GRADIENT_CLIP_NORM             5.0
# IMAGES_PER_GPU                 1
# IMAGE_CHANNEL_COUNT            3
# IMAGE_MAX_DIM                  128
# IMAGE_META_SIZE                43
# IMAGE_MIN_DIM                  128
# IMAGE_MIN_SCALE                0
# IMAGE_RESIZE_MODE              square
# IMAGE_SHAPE                    [128 128   3]
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.001
# LOSS_WEIGHTS                   {'rpn_class_loss': 1.0, 'rpn_bbox_loss': 1.0, 'mrcnn_class_loss': 1.0, 'mrcnn_bbox_loss': 1.0, 'mrcnn_mask_loss': 1.0}
# MASK_POOL_SIZE                 14
# MASK_SHAPE                     [28, 28]
# MAX_GT_INSTANCES               100
# MEAN_PIXEL                     [123.7 116.8 103.9]
# MINI_MASK_SHAPE                (56, 56)
# NAME                           detection
# NUM_CLASSES                    31
# POOL_SIZE                      7
# POST_NMS_ROIS_INFERENCE        1000
# POST_NMS_ROIS_TRAINING         2000
# PRE_NMS_LIMIT                  6000
# ROI_POSITIVE_RATIO             0.33
# RPN_ANCHOR_RATIOS              [0.5, 1, 2]
# RPN_ANCHOR_SCALES              (8, 16, 32, 64, 128)
# RPN_ANCHOR_STRIDE              1
# RPN_BBOX_STD_DEV               [0.1 0.1 0.2 0.2]
# RPN_NMS_THRESHOLD              0.7
# RPN_TRAIN_ANCHORS_PER_IMAGE    256
# STEPS_PER_EPOCH                100
# TOP_DOWN_PYRAMID_SIZE          256
# TRAIN_BN                       False
# TRAIN_ROIS_PER_IMAGE           32
# USE_MINI_MASK                  True
# USE_RPN_ROIS                   True
# VALIDATION_STEPS               5
# WEIGHT_DECAY                   0.0001
#
#
# WARNING:tensorflow:From /home/sh/anaconda3/envs/dl/lib/python3.6/site-packages/tensorflow/python/ops/sparse_ops.py:1165: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# Re-starting from epoch 1000
# Re-starting from epoch 1010
# Re-starting from epoch 1020
# Re-starting from epoch 1030
# Re-starting from epoch 1040
# Re-starting from epoch 1050
# Re-starting from epoch 1060
# Re-starting from epoch 1070
# Re-starting from epoch 1080
# Re-starting from epoch 1090
# Re-starting from epoch 1100
# Re-starting from epoch 1110
# Re-starting from epoch 1120
# Re-starting from epoch 1130
# Re-starting from epoch 1140
# Re-starting from epoch 1150
# Re-starting from epoch 1160
# Re-starting from epoch 1170
# Re-starting from epoch 1180
# Re-starting from epoch 1190
# Re-starting from epoch 1200
# Re-starting from epoch 1210
# Re-starting from epoch 1220
# Re-starting from epoch 1230
# Re-starting from epoch 1240
# Re-starting from epoch 1250
# Re-starting from epoch 1260
# Re-starting from epoch 1270
# Re-starting from epoch 1280
# Re-starting from epoch 1290
# Re-starting from epoch 1300
# Re-starting from epoch 1310
# Re-starting from epoch 1320
# Re-starting from epoch 1330
# Re-starting from epoch 1340
# Re-starting from epoch 1350
# Re-starting from epoch 1360
# Re-starting from epoch 1370
# Re-starting from epoch 1380
# Re-starting from epoch 1390
# Re-starting from epoch 1400
# Re-starting from epoch 1410
# Re-starting from epoch 1420
# Re-starting from epoch 1430
# Re-starting from epoch 1440
# Re-starting from epoch 1450
# Re-starting from epoch 1460
# Re-starting from epoch 1470
# Re-starting from epoch 1480
# Re-starting from epoch 1490
# Re-starting from epoch 1500
# Re-starting from epoch 1510
# Re-starting from epoch 1520
# Re-starting from epoch 1530
# Re-starting from epoch 1540
# Re-starting from epoch 1550
# Re-starting from epoch 1560
# Re-starting from epoch 1570
# Re-starting from epoch 1580
# Re-starting from epoch 1590
# Re-starting from epoch 1600
# Re-starting from epoch 1610
# Re-starting from epoch 1620
# Re-starting from epoch 1630
# Re-starting from epoch 1640
# Re-starting from epoch 1650
# Re-starting from epoch 1660
# Re-starting from epoch 1670
# Re-starting from epoch 1680
# Re-starting from epoch 1690
# Re-starting from epoch 1700
# Re-starting from epoch 1710
# Re-starting from epoch 1720
# Re-starting from epoch 1730
# Re-starting from epoch 1740
# Re-starting from epoch 1750
# Re-starting from epoch 1760
# Re-starting from epoch 1770
# Re-starting from epoch 1780
# Re-starting from epoch 1790
# Re-starting from epoch 1800
# Re-starting from epoch 1810
# Re-starting from epoch 1820
# Re-starting from epoch 1830
# Re-starting from epoch 1840
# Re-starting from epoch 1850
# Re-starting from epoch 1860
# Re-starting from epoch 1870
# Re-starting from epoch 1880
# Re-starting from epoch 1890
# Re-starting from epoch 1900
# Re-starting from epoch 1910
# Re-starting from epoch 1920
# Re-starting from epoch 1930
# Re-starting from epoch 1940
# Re-starting from epoch 1950
# Re-starting from epoch 1960
# Re-starting from epoch 1970
# Re-starting from epoch 1980
# Re-starting from epoch 1990
# Re-starting from epoch 2000
# Re-starting from epoch 2010
# Re-starting from epoch 2020
# Re-starting from epoch 2030
# Re-starting from epoch 2040
# Re-starting from epoch 2050
# Re-starting from epoch 2060
# Re-starting from epoch 2070
# Re-starting from epoch 2080
# Re-starting from epoch 2090
# Re-starting from epoch 2100
# Re-starting from epoch 2110
# Re-starting from epoch 2120
# Re-starting from epoch 2130
# Re-starting from epoch 2140
# Re-starting from epoch 2150
# Re-starting from epoch 2160
# Re-starting from epoch 2170
# Re-starting from epoch 2180
# Re-starting from epoch 2190
# Re-starting from epoch 2200
# Re-starting from epoch 2210
# Re-starting from epoch 2220
# Re-starting from epoch 2230
# Re-starting from epoch 2240
# Re-starting from epoch 2250
# Re-starting from epoch 2260
# Re-starting from epoch 2270
# Re-starting from epoch 2280
# Re-starting from epoch 2290
# Re-starting from epoch 2300
# Re-starting from epoch 2310
# Re-starting from epoch 2320
# Re-starting from epoch 2330
# Re-starting from epoch 2340
# Re-starting from epoch 2350
# Re-starting from epoch 2360
# Re-starting from epoch 2370
# Re-starting from epoch 2380
# Re-starting from epoch 2390
# Re-starting from epoch 2400
# Re-starting from epoch 2410
# Re-starting from epoch 2420
# Re-starting from epoch 2430
# Re-starting from epoch 2440
# Re-starting from epoch 2450
# Re-starting from epoch 2460
# Re-starting from epoch 2470
# Re-starting from epoch 2480
# Re-starting from epoch 2490
# Re-starting from epoch 2500
# Re-starting from epoch 2510
# Re-starting from epoch 2520
# Re-starting from epoch 2530
# Re-starting from epoch 2540
# Re-starting from epoch 2550
# Re-starting from epoch 2560
# Re-starting from epoch 2570
# Re-starting from epoch 2580
# Re-starting from epoch 2590
# Re-starting from epoch 2600
# Re-starting from epoch 2610
# Re-starting from epoch 2620
# Re-starting from epoch 2630
# Re-starting from epoch 2640
# Re-starting from epoch 2650
# Re-starting from epoch 2660
# Re-starting from epoch 2670
# Re-starting from epoch 2680
# Re-starting from epoch 2690
# Re-starting from epoch 2700
# Re-starting from epoch 2710
# Re-starting from epoch 2720
# Re-starting from epoch 2730
# Re-starting from epoch 2740
# Re-starting from epoch 2750
# Re-starting from epoch 2760
# Re-starting from epoch 2770
# Re-starting from epoch 2780
# Re-starting from epoch 2790
# Re-starting from epoch 2800
# Re-starting from epoch 2810
# Re-starting from epoch 2820
# Re-starting from epoch 2830
# Re-starting from epoch 2840
# Re-starting from epoch 2850
# Re-starting from epoch 2860
# Re-starting from epoch 2870
# Re-starting from epoch 2880
# Re-starting from epoch 2890
# Re-starting from epoch 2900
# Re-starting from epoch 2910
# Re-starting from epoch 2920
# Re-starting from epoch 2930
# Re-starting from epoch 2940
# Re-starting from epoch 2950
# Re-starting from epoch 2960
# Re-starting from epoch 2970
# Re-starting from epoch 2980
# Re-starting from epoch 2990
# Re-starting from epoch 3000

# %%
curv = zip(x,y)
for x in curv:
  print(x)
# Out:
# (1000, 0.5540540540540541)
# (1010, 0.5743243243243243)
# (1020, 0.5)
# (1030, 0.6486486486486487)
# (1040, 0.6114864864864865)
# (1050, 0.49324324324324326)
# (1060, 0.5371621621621622)
# (1070, 0.581081081081081)
# (1080, 0.6925675675675675)
# (1090, 0.668918918918919)
# (1100, 0.6418918918918919)
# (1110, 0.6385135135135135)
# (1120, 0.6554054054054054)
# (1130, 0.6959459459459459)
# (1140, 0.7162162162162162)
# (1150, 0.6554054054054054)
# (1160, 0.6013513513513513)
# (1170, 0.6891891891891891)
# (1180, 0.6993243243243243)
# (1190, 0.6858108108108109)
# (1200, 0.6959459459459459)
# (1210, 0.6824324324324325)
# (1220, 0.7027027027027027)
# (1230, 0.7635135135135135)
# (1240, 0.7128378378378378)
# (1250, 0.7398648648648649)
# (1260, 0.6655405405405406)
# (1270, 0.7128378378378378)
# (1280, 0.7331081081081081)
# (1290, 0.7398648648648649)
# (1300, 0.7331081081081081)
# (1310, 0.7331081081081081)
# (1320, 0.6959459459459459)
# (1330, 0.7094594594594594)
# (1340, 0.6959459459459459)
# (1350, 0.722972972972973)
# (1360, 0.7297297297297297)
# (1370, 0.7398648648648649)
# (1380, 0.7533783783783784)
# (1390, 0.7364864864864865)
# (1400, 0.7195945945945946)
# (1410, 0.7702702702702703)
# (1420, 0.7567567567567568)
# (1430, 0.7162162162162162)
# (1440, 0.6959459459459459)
# (1450, 0.7432432432432432)
# (1460, 0.6891891891891891)
# (1470, 0.7162162162162162)
# (1480, 0.625)
# (1490, 0.6858108108108109)
# (1500, 0.7297297297297297)
# (1510, 0.6959459459459459)
# (1520, 0.7027027027027027)
# (1530, 0.6790540540540541)
# (1540, 0.6959459459459459)
# (1550, 0.7094594594594594)
# (1560, 0.7331081081081081)
# (1570, 0.7128378378378378)
# (1580, 0.7331081081081081)
# (1590, 0.706081081081081)
# (1600, 0.7837837837837838)
# (1610, 0.7601351351351351)
# (1620, 0.7668918918918919)
# (1630, 0.7297297297297297)
# (1640, 0.7567567567567568)
# (1650, 0.7635135135135135)
# (1660, 0.7736486486486487)
# (1670, 0.7635135135135135)
# (1680, 0.75)
# (1690, 0.7668918918918919)
# (1700, 0.7635135135135135)
# (1710, 0.777027027027027)
# (1720, 0.7635135135135135)
# (1730, 0.7601351351351351)
# (1740, 0.7601351351351351)
# (1750, 0.7364864864864865)
# (1760, 0.7364864864864865)
# (1770, 0.7567567567567568)
# (1780, 0.7601351351351351)
# (1790, 0.6993243243243243)
# (1800, 0.6013513513513513)
# (1810, 0.7027027027027027)
# (1820, 0.7567567567567568)
# (1830, 0.6655405405405406)
# (1840, 0.6959459459459459)
# (1850, 0.7263513513513513)
# (1860, 0.722972972972973)
# (1870, 0.7837837837837838)
# (1880, 0.7094594594594594)
# (1890, 0.7533783783783784)
# (1900, 0.7567567567567568)
# (1910, 0.6756756756756757)
# (1920, 0.7331081081081081)
# (1930, 0.6655405405405406)
# (1940, 0.7263513513513513)
# (1950, 0.7297297297297297)
# (1960, 0.6959459459459459)
# (1970, 0.6993243243243243)
# (1980, 0.7128378378378378)
# (1990, 0.6925675675675675)
# (2000, 0.6993243243243243)
# (2010, 0.7905405405405406)
# (2020, 0.75)
# (2030, 0.75)
# (2040, 0.7094594594594594)
# (2050, 0.7297297297297297)
# (2060, 0.7297297297297297)
# (2070, 0.7466216216216216)
# (2080, 0.7094594594594594)
# (2090, 0.7297297297297297)
# (2100, 0.7195945945945946)
# (2110, 0.7128378378378378)
# (2120, 0.722972972972973)
# (2130, 0.7432432432432432)
# (2140, 0.8006756756756757)
# (2150, 0.75)
# (2160, 0.7567567567567568)
# (2170, 0.7297297297297297)
# (2180, 0.7668918918918919)
# (2190, 0.7635135135135135)
# (2200, 0.75)
# (2210, 0.75)
# (2220, 0.7162162162162162)
# (2230, 0.7533783783783784)
# (2240, 0.7567567567567568)
# (2250, 0.7533783783783784)
# (2260, 0.6959459459459459)
# (2270, 0.7094594594594594)
# (2280, 0.75)
# (2290, 0.7702702702702703)
# (2300, 0.7635135135135135)
# (2310, 0.8040540540540541)
# (2320, 0.7567567567567568)
# (2330, 0.7635135135135135)
# (2340, 0.7905405405405406)
# (2350, 0.7668918918918919)
# (2360, 0.7871621621621622)
# (2370, 0.7871621621621622)
# (2380, 0.7736486486486487)
# (2390, 0.8006756756756757)
# (2400, 0.7702702702702703)
# (2410, 0.7871621621621622)
# (2420, 0.7635135135135135)
# (2430, 0.7635135135135135)
# (2440, 0.7837837837837838)
# (2450, 0.7331081081081081)
# (2460, 0.7635135135135135)
# (2470, 0.7533783783783784)
# (2480, 0.7128378378378378)
# (2490, 0.7567567567567568)
# (2500, 0.7432432432432432)
# (2510, 0.7432432432432432)
# (2520, 0.7668918918918919)
# (2530, 0.8074324324324325)
# (2540, 0.7601351351351351)
# (2550, 0.7297297297297297)
# (2560, 0.777027027027027)
# (2570, 0.7905405405405406)
# (2580, 0.7297297297297297)
# (2590, 0.7736486486486487)
# (2600, 0.7804054054054054)
# (2610, 0.7736486486486487)
# (2620, 0.722972972972973)
# (2630, 0.7702702702702703)
# (2640, 0.7702702702702703)
# (2650, 0.7094594594594594)
# (2660, 0.7567567567567568)
# (2670, 0.7567567567567568)
# (2680, 0.7668918918918919)
# (2690, 0.7635135135135135)
# (2700, 0.7635135135135135)
# (2710, 0.7297297297297297)
# (2720, 0.7702702702702703)
# (2730, 0.777027027027027)
# (2740, 0.7128378378378378)
# (2750, 0.7702702702702703)
# (2760, 0.793918918918919)
# (2770, 0.793918918918919)
# (2780, 0.7905405405405406)
# (2790, 0.7432432432432432)
# (2800, 0.7094594594594594)
# (2810, 0.7533783783783784)
# (2820, 0.7905405405405406)
# (2830, 0.7432432432432432)
# (2840, 0.7533783783783784)
# (2850, 0.7905405405405406)
# (2860, 0.7837837837837838)
# (2870, 0.7736486486486487)
# (2880, 0.7635135135135135)
# (2890, 0.7398648648648649)
# (2900, 0.7533783783783784)
# (2910, 0.7804054054054054)
# (2920, 0.7635135135135135)
# (2930, 0.7668918918918919)
# (2940, 0.7804054054054054)
# (2950, 0.7972972972972973)
# (2960, 0.777027027027027)
# (2970, 0.8175675675675675)
# (2980, 0.793918918918919)
# (2990, 0.7533783783783784)
# (3000, 0.7972972972972973)
